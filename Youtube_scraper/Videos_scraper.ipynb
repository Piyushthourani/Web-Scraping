# %%
import time
import requests
import numpy as np
import pandas as pd
from tqdm import tqdm
from bs4 import BeautifulSoup
from selenium import webdriver

driver = webdriver.Chrome()

# %%
df = pd.read_csv('data.csv')
df.head()
# Out:
#                                      video_link  \
# 0  https://www.youtube.com//watch?v=W3I3kAg2J7w
# 1  https://www.youtube.com//watch?v=eMlx5fFNoYc
# 2  https://www.youtube.com//watch?v=wjZofJX0v4M
# 3  https://www.youtube.com//watch?v=Cz4Q4QOuoo8
# 4  https://www.youtube.com//watch?v=KTzGBJPuJwM
#
#                                      thumbnail_link                duration
# 0  https://i.ytimg.com/vi/W3I3kAg2J7w/hqdefault.jpg  15 minutes, 30 seconds
# 1  https://i.ytimg.com/vi/eMlx5fFNoYc/hqdefault.jpg  26 minutes, 10 seconds
# 2  https://i.ytimg.com/vi/wjZofJX0v4M/hqdefault.jpg  27 minutes, 14 seconds
# 3  https://i.ytimg.com/vi/Cz4Q4QOuoo8/hqdefault.jpg  13 minutes, 25 seconds
# 4  https://i.ytimg.com/vi/KTzGBJPuJwM/hqdefault.jpg  29 minutes, 24 seconds

# %%
data = []

for i in tqdm(df['video_link']):
    
    driver.get(i)
    driver.execute_script("window.scrollTo(0, 200)")
    time.sleep(2)
    driver.execute_script("window.scrollTo(0, 200)")
    time.sleep(1)
    driver.execute_script("window.scrollTo(0, 200)")
    time.sleep(1)

    soup = BeautifulSoup(driver.page_source, 'html.parser')
    
    try:
        title = soup.find_all('yt-formatted-string', class_ = 'style-scope ytd-video-primary-info-renderer')[0].text
    except:
        title = np.nan
    
    try:
        date  = soup.find_all('yt-formatted-string', class_ = 'style-scope ytd-video-primary-info-renderer')[1].text
    except:
        date = np.nan
        
    try:
        views = soup.find('span', class_ = 'view-count style-scope ytd-video-view-count-renderer').text.split(' ')[0]
    except:
        views = np.nan
        
    try:
        likes = soup.find('yt-formatted-string', class_ = 'style-scope ytd-toggle-button-renderer style-text').text
    except:
        likes = np.nan
        
    try:
        description = soup.find('yt-formatted-string', class_ = 'content style-scope ytd-video-secondary-info-renderer').text
    except:
        description = np.nan
        
    try:
        comment = soup.find('ytd-comments-header-renderer').find('h2').find('span').text
    except:
        comment = np.nan
    
    data.append([title, views, likes, comment, date, description])
# Out:
# 100%|██████████| 128/128 [18:33<00:00,  8.70s/it]

# %%
len(data)
# Out:
# 128

# %%
data = np.array(data)

# %%
title = data[:,:1]
views = data[:,1:2]
likes = data[:,2:3]
comments = data[:,3:4]
date = data[:,4:5]
description = data[:,5:6]

# %%
df['title'] = title
df['views'] = views
df['likes'] = likes
df['comments'] = comments
df['date'] = date
df['description'] = description

# %%
df.isnull().sum()
# Out:
# video_link        0
# thumbnail_link    0
# duration          0
# title             0
# views             0
# likes             0
# comments          0
# date              0
# description       0
# dtype: int64

# %%
df
# Out:
#                                        video_link  \
# 0    https://www.youtube.com//watch?v=W3I3kAg2J7w
# 1    https://www.youtube.com//watch?v=eMlx5fFNoYc
# 2    https://www.youtube.com//watch?v=wjZofJX0v4M
# 3    https://www.youtube.com//watch?v=Cz4Q4QOuoo8
# 4    https://www.youtube.com//watch?v=KTzGBJPuJwM
# ..                                            ...
# 123  https://www.youtube.com//watch?v=1SMmc9gQmHQ
# 124  https://www.youtube.com//watch?v=XFDM1ip5HdU
# 125  https://www.youtube.com//watch?v=-9OUyo8NFZg
# 126  https://www.youtube.com//watch?v=zLzLxVeqdQg
# 127  https://www.youtube.com//watch?v=F_0yfvm0UoU
#
#                                        thumbnail_link                duration  \
# 0    https://i.ytimg.com/vi/W3I3kAg2J7w/hqdefault.jpg  15 minutes, 30 seconds
# 1    https://i.ytimg.com/vi/eMlx5fFNoYc/hqdefault.jpg  26 minutes, 10 seconds
# 2    https://i.ytimg.com/vi/wjZofJX0v4M/hqdefault.jpg  27 minutes, 14 seconds
# 3    https://i.ytimg.com/vi/Cz4Q4QOuoo8/hqdefault.jpg  13 minutes, 25 seconds
# 4    https://i.ytimg.com/vi/KTzGBJPuJwM/hqdefault.jpg  29 minutes, 24 seconds
# ..                                                ...                     ...
# 123  https://i.ytimg.com/vi/1SMmc9gQmHQ/hqdefault.jpg   2 minutes, 34 seconds
# 124  https://i.ytimg.com/vi/XFDM1ip5HdU/hqdefault.jpg   15 minutes, 8 seconds
# 125  https://i.ytimg.com/vi/-9OUyo8NFZg/hqdefault.jpg   7 minutes, 27 seconds
# 126  https://i.ytimg.com/vi/zLzLxVeqdQg/hqdefault.jpg     1 minute, 4 seconds
# 127  https://i.ytimg.com/vi/F_0yfvm0UoU/hqdefault.jpg   6 minutes, 14 seconds
#
#                                                  title      views likes  \
# 0    What "Follow Your Dreams" Misses | Harvey Mudd...  1,236,070   nan
# 1    Attention in transformers, step-by-step | Deep...  2,889,629   nan
# 2    Transformers, the tech behind LLMs | Deep Lear...  6,933,624   nan
# 3          Answering viewer questions about refraction    959,521   nan
# 4    But why would light "slow down"? | Visualizing...  2,155,859   nan
# ..                                                 ...        ...   ...
# 123                  How to count to 1000 on two hands    440,873   nan
# 124             What does it feel like to invent math?  4,405,249   nan
# 125                  Euler's Formula and Graph Duality    500,073   nan
# 126                               Euler's Formula Poem    174,127   nan
# 127  e to the pi i, a nontraditional take (old vers...  2,721,985   nan
#
#     comments          date description
# 0        nan  May 18, 2024         nan
# 1        nan   Apr 7, 2024         nan
# 2        nan   Apr 2, 2024         nan
# 3        nan   Dec 3, 2023         nan
# 4      2,197   Dec 1, 2023         nan
# ..       ...           ...         ...
# 123      nan  Sep 19, 2015         nan
# 124    6,061  Aug 14, 2015         nan
# 125      nan  Jun 21, 2015         nan
# 126      nan   Mar 5, 2015         nan
# 127      nan   Mar 5, 2015         nan
#
# [128 rows x 9 columns]
