# %%
import requests
from bs4 import BeautifulSoup

# %%
URL = "http://www.values.com/inspirational-quotes"
r = requests.get(URL)
r
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(r.content, 'html5lib') # If this line causes an error, run 'pip install html5lib' or install html5lib
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="no-js" dir="ltr" lang="en-US">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width,initial-scale=1.0" name="viewport"/>
#   <title>
#    Inspirational Quotes - Motivational Quotes - | The Foundation for a Better Life
#   </title>
#   <meta content="Find the perfect quotation from our hand-picked collection of inspiring quotes by hundreds of authors." name="description"/>
#   <meta content="pass, it, on, passiton, values, kindness" name="keywords"/>
#   <meta content="The Foundation for a Better Life" name="twitter:site_name"/>
#   <meta content="@passiton_values" name="twitter:site"/>
#   <meta content="summary" name="twitter:card"/>
#   <meta content="Thank you for visiting." name="twitter:description"/>
#   <meta content="https://www.passiton.com/passiton_fbl.jpg" name="twitter:image"/>
#   <meta content="https://www.passiton.com/inspirational-quotes" property="og:url"/>
#   <meta content="The Foundation for a Better Life" property="og:site_name"/>
#   <meta content="Welcome to PassItOn.com" property="og:title"/>
#   <meta content="https://www.passiton.com/passiton_fbl.jpg" property="og:image"/>
#   <meta content="Thank you for visiting." property="og:description"/>
#   <meta content="website" property="og:type"/>
#   <link href="/apple-touch-icon.png" rel="apple-touch-icon" sizes="180x180"/>
#   <link href="/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
#   <link href="/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
#   <link href="/site.webmanifest" rel="manifest"/>
#   <link color="#c8102e" href="/safari-pinned-tab.svg" rel="mask-icon"/>
#   <meta content="#ffffff" name="msapplication-TileColor"/>
#   <meta content="#ffffff" name="theme-color"/>
#   <script data-turbo-track="reload" defer="defer" src="https://challenges.cloudflare.com/turnstile/v0/api.js">
#   </script>
#   <link crossorigin="anonymous" href="https://stackpath.bootstrapcdn.com/bootstrap/4.3.1/css/bootstrap.min.css" integrity="sha384-ggOyR0iXCbMQv3Xipma34MD+dH/1fQ784/j6cY/iJTQUOhcWr7x9JvoRxT2MZw1T" rel="stylesheet"/>
#   <link data-turbo-track="reload" href="/assets/application-33a988700c26471ae2b23b036ea973689983d128a304cdc90b0e27062a395255.css" rel="stylesheet"/>
#   <meta content="authenticity_token" name="csrf-param"/>
#   <meta content="KeUGO7tIjuJodvcTxU5WivqiZwMiNTDT4H7XNu2K2WEJ53_PZsA4h1SM8OTXqzgnOO1V2cucSk0OSN-szB0Ifw" name="csrf-token"/>
#   <link href="https://www.passiton.com/inspirational-quotes.atom" rel="alternate" title="RSS" type="application/rss+xml"/>
#  </head>
#  <body class="no-transition quotes_index">
#   <header>
#    <nav class="navbar navbar-default bootsnav background-transparent header-dark white-link navbar-fixed-top navbar-expand-lg nav-box-width">
#     <div class="container-fluid nav-header-container">
#      <div class="col-auto pl-0">
#       <a class="logo" href="/" title="Pass It On®">
#        <img alt="Pass It On" class="logo-dark" data-rjs="/assets/site/logo@2x-a5b7e9de4b8595ff3fc94c64e245592585dda8a14753ab6d4ce6a8e56155f543.png" src="/assets/site/logo-addf119432237cf6c743df6160193cf0c428b2bb9f6f258fef3f3fa1c710dd59.png"/>
#        <img alt="Pass It On" class="logo-light default" data-rjs="/assets/site/logo-white@2x-d49e37762eb5c6805d094397a8bca8b53d38c872c1fc54195093caff0208ad77.png" src="/assets/site/logo-white-cc0fccfb11de6149582eafd4805e8422c93875f0df879d387c1ac38a36dbead8.png"/>
#       </a>
#      </div>
#      <div class="col accordion-menu pr-0 pr-md-3">
#       <button class="navbar-toggler collapsed" data-target="#navbar-collapse-toggle-1" data-toggle="collapse" type="button">
#        <span class="sr-only">
#         toggle navigation
#        </span>
#        <span class="icon-bar">
#        </span>
#        <span class="icon-bar">
#        </span>
#        <span class="icon-bar">
#        </span>
#       </button>
#       <div class="navbar-collapse collapse justify-content-end" id="navbar-collapse-toggle-1">
#        <ul class="nav navbar-nav navbar-left no-margin alt-font text-normal" data-in="fadeIn" data-out="fadeOut" id="accordion">
#         <li>
#          <a href="/inspirational-quotes">
#           Quotes
#          </a>
#         </li>
#         <li class="dropdown simple-dropdown">
#          <a href="/inspirational-stories-tv-spots">
#           Videos
#           <i aria-hidden="true" class="fas fa-caret-down d-none d-lg-inline">
#           </i>
#          </a>
#          <i aria-hidden="true" class="fas fa-caret-down dropdown-toggle" data-toggle="dropdown">
#          </i>
#          <ul class="dropdown-menu" role="menu">
#           <li>
#            <a href="/inspirational-stories-tv-spots">
#             Official Pass It On® Videos
#            </a>
#           </li>
#           <li>
#            <a href="/artcenter-psas">
#             ArtCenter College of Design PSAs
#            </a>
#           </li>
#          </ul>
#         </li>
#         <li class="dropdown simple-dropdown">
#          <a href="/inspirational-sayings-billboards">
#           Billboards
#           <i aria-hidden="true" class="fas fa-caret-down d-none d-lg-inline">
#           </i>
#          </a>
#          <i aria-hidden="true" class="fas fa-caret-down dropdown-toggle" data-toggle="dropdown">
#          </i>
#          <ul class="dropdown-menu" role="menu">
#           <li>
#            <a href="/inspirational-sayings-billboards">
#             Official Billboards
#            </a>
#           </li>
#           <li>
#            <a href="/is-in-you">
#             Is In You® Billboards
#            </a>
#           </li>
#          </ul>
#         </li>
#         <li class="dropdown simple-dropdown">
#          <a href="/positive-good-news-stories">
#           Stories
#           <i aria-hidden="true" class="fas fa-caret-down d-none d-lg-inline">
#           </i>
#          </a>
#          <i aria-hidden="true" class="fas fa-caret-down dropdown-toggle" data-toggle="dropdown">
#          </i>
#          <ul class="dropdown-menu" role="menu">
#           <li>
#            <a href="/positive-good-news-stories">
#             Positive Good News Stories
#            </a>
#           </li>
#           <li>
#            <a href="/free-ebook/download">
#             <span class="new">
#              FREE
#             </span>
#             PassItOn® Stories eBook
#            </a>
#           </li>
#          </ul>
#         </li>
#         <li>
#          <a href="/inspirational-audio-stories">
#           Podcast
#          </a>
#         </li>
#         <li>
#          <a href="/radio">
#           Radio
#          </a>
#         </li>
#         <li>
#          <a href="/passiton-blog">
#           Blog
#          </a>
#         </li>
#         <li class="dropdown simple-dropdown">
#          <a href="/poster-requests/new">
#           Schools
#           <i aria-hidden="true" class="fas fa-caret-down d-none d-lg-inline">
#           </i>
#          </a>
#          <i aria-hidden="true" class="fas fa-caret-down dropdown-toggle" data-toggle="dropdown">
#          </i>
#          <ul class="dropdown-menu" role="menu">
#           <li>
#            <a href="/poster-requests/new">
#             FREE Posters
#            </a>
#           </li>
#           <li>
#            <a href="/free-ebook/download">
#             <span class="new">
#              FREE
#             </span>
#             PassItOn® Stories eBook
#            </a>
#           </li>
#           <li>
#            <a href="/positive-good-news-stories">
#             <span class="new">
#              NEW
#             </span>
#             Inspirational Stories
#            </a>
#           </li>
#           <li>
#            <a href="/pass-it-on-downloads">
#             PDF Poster Downloads
#            </a>
#           </li>
#           <li>
#            <a href="/pass-it-on-downloads#passiton_bookmarks">
#             Bookmark Downloads
#            </a>
#           </li>
#          </ul>
#         </li>
#         <li class="dropdown simple-dropdown">
#          <a href="#">
#           <i aria-hidden="true" class="fas fa-globe d-none d-lg-inline text-normal">
#           </i>
#           <i aria-hidden="true" class="fas fa-caret-down d-none d-lg-inline">
#           </i>
#          </a>
#          <i aria-hidden="true" class="fas fa-caret-down dropdown-toggle" data-toggle="dropdown">
#          </i>
#          <ul class="dropdown-menu" role="menu">
#           <li>
#            <a href="https://www.pasala.org/" target="_blank">
#             Spanish | Español
#            </a>
#           </li>
#           <li>
#            <a href="https://www.umavidamelhor.org/" target="_blank">
#             Portuguese | Português
#            </a>
#           </li>
#           <li>
#            <a href="https://www.values.cn.com/" target="_blank">
#             Chinese | 中文
#            </a>
#           </li>
#          </ul>
#         </li>
#        </ul>
#       </div>
#      </div>
#      <div class="col-auto pr-0">
#       <div class="header-searchbar">
#        <a aria-label="search form" class="header-search-form" href="#search-header">
#         <i class="fas fa-search search-button">
#         </i>
#        </a>
#        <form action="/search" class="mfp-hide search-form-result" id="search-header" method="post" name="search-header">
#         <div class="search-form position-relative">
#          <button aria-label="Search" class="fas fa-search close-search search-button" type="submit">
#          </button>
#          <input autocomplete="off" class="search-input" name="q" placeholder="Search passiton.com..." type="text"/>
#         </div>
#        </form>
#       </div>
#      </div>
#     </div>
#    </nav>
#   </header>
#   <section class="parallax padding-six-all bg-black" data-stellar-background-ratio="0.2" style="background-image:url('/assets/backgrounds/flowers-7e362d59b798265063c210d16ea800b6fb4c3b13e462fbfe195df7c70c9811ce.jpg');">
#    <div class="container">
#     <div class="row justify-content-center">
#      <div class="col-12 col-lg-10 text-center">
#       <div class="shadow bg-extra-dark-gray padding-two-all border-radius-6 width-70 lg-width-80 sm-width-100 mx-auto lg-padding-30px-all sm-padding-15px-all sm-margin-40px-top">
#        <h6 class="font-weight-300 text-white-2 margin-20px-bottom sm-margin-15px-bottom">
#         Get our FREE daily quote emails!
#        </h6>
#        <p class="text-medium text-white-2 width-70 mx-auto margin-40px-bottom sm-width-100 sm-margin-15px-bottom">
#         Get a daily inspirational quote in your inbox each weekday! Enter your email below to subscribe.
#        </p>
#        <form accept-charset="UTF-8" action="/users" class="simple_form search-box3 margin-10px-bottom" id="new_user" method="post" novalidate="novalidate">
#         <input autocomplete="off" name="authenticity_token" type="hidden" value="a3BcE5MnMJfubm-GANftKisWjmArB5xzw0lOLWf4kRUlYtQHTbiD2quop0n-0UdVA1fNPoHtM0-8DbeYAuA_2w"/>
#         <div class="input-group add-on width-75 mx-auto sm-width-100">
#          <input class="string email optional form-control text-white" id="user_email" label="false" name="user[email]" placeholder="you@youremail.com" type="text" value=""/>
#          <div class="input-group-append">
#           <button aria-label="Submit" class="btn btn-default" type="submit">
#            <i class="ti-arrow-right text-small m-0">
#            </i>
#           </button>
#          </div>
#         </div>
#         <div class="cf-turnstile margin-10px-top" data-callback="javascriptCallback" data-sitekey="0x4AAAAAAASgRtNBQYE3dg9n">
#         </div>
#        </form>
#       </div>
#      </div>
#     </div>
#    </div>
#   </section>
#   <section class="half-section bg-extra-dark-gray half-section">
#    <div class="container">
#     <div class="row m-0">
#      <div class="col-12 d-flex flex-column justify-content-center text-center wow fadeIn" data-wow-delay="0.2s">
#       <h5 class="text-white alt-font font-weight-400 letter-spacing-1 margin-10px-bottom">
#        INSPIRATIONAL QUOTES
#       </h5>
#       <span class="text-white-2 opacity8 alt-font mb-0 padding-20px-bottom">
#        Find the perfect quote... and Pass It On®
#       </span>
#       <form action="/inspirational-quotes" class="search-box2 margin-30px-bottom" method="get">
#        <div class="input-group add-on width-75 mx-auto sm-width-100">
#         <input class="form-control text-white-2" name="q" placeholder="Search our inspiring quotes..." type="text" value=""/>
#         <div class="input-group-append">
#          <button aria-label="Search" class="btn btn-default" type="submit">
#           <i class="ti-search text-small m-0">
#           </i>
#          </button>
#         </div>
#        </div>
#       </form>
#      </div>
#     </div>
#     <div class="row m-0">
#      <div class="col-12 d-flex flex-column justify-content-top text-center">
#       <div class="row" id="all_quotes">
#        <div class="col-6 col-lg-3 text-center margin-30px-bottom sm-margin-30px-top">
#         <a href="/inspirational-quotes/4468-careers-like-rockets-dont-always-take-off-on">
#          <img alt="Careers, like rockets, don't always take off on schedule. The key is to keep working the engines. #&lt;Author:0x00007f6e506f7320&gt;" class="margin-10px-bottom shadow" height="310" src="https://assets.passiton.com/quotes/quote_artwork/4468/medium/20250709_wednesday_quote.jpg" width="310"/>
#         </a>
#         <h5 class="value_on_red">
#          <a href="/inspirational-quotes/4468-careers-like-rockets-dont-always-take-off-on">
#           HARD WORK
#          </a>
#         </h5>
#        </div>
#        <div class="col-6 col-lg-3 text-center margin-30px-bottom sm-margin-30px-top">
#         <a href="/inspirational-quotes/8378-doing-the-best-at-this-moment-puts-you-in-the">
#          <img alt="Doing the best at this moment puts you in the best place for the next moment. #&lt;Author:0x00007f6e506f3680&gt;" class="margin-10px-bottom shadow" height="310" src="https://assets.passiton.com/quotes/quote_artwork/8378/medium/20250708_tuesday_quote.jpg" width="310"/>
#         </a>
#         <h5 class="value_on_red">
#          <a href="/inspirational-quotes/8378-doing-the-best-at-this-moment-puts-you-in-the">
#           HARD WORK
#          </a>
#         </h5>
#        </div>
#        <div class="col-6 col-lg-3 text-center margin-30px-bottom sm-margin-30px-top">
#         <a href="/inspirational-quotes/6188-far-and-away-the-best-prize-that-life-offers-is">
#          <img alt="Far and away the best prize that life offers is the chance to work hard at work worth doing.  #&lt;Author:0x00007f6e506f0340&gt;" class="margin-10px-bottom shadow" height="310" src="https://assets.passiton.com/quotes/quote_artwork/6188/medium/20250707_monday_quote.jpg" width="310"/>
#         </a>
#         <h5 class="value_on_red">
#          <a href="/inspirational-quotes/6188-far-and-away-the-best-prize-that-life-offers-is">
#           HARD WORK
#          </a>
#         </h5>
#        </div>
#        <div class="col-6 col-lg-3 text-center margin-30px-bottom sm-margin-30px-top">
#         <a href="/inspirational-quotes/8447-from-every-mountainside-let-freedom-ring">
#          <img alt="From every mountainside, let freedom ring. #&lt;Author:0x00007f6e5075bff0&gt;" class="margin-10px-bottom shadow" height="310" src="https://assets.passiton.com/quotes/quote_artwork/8447/medium/20250704_friday_quote.jpg" width="310"/>
#         </a>
#         <h5 class="value_on_red">
#          <a href="/inspirational-quotes/8447-from-every-mountainside-let-freedom-ring">
#           FREEDOM
#          </a>
#         </h5>
#        </div>
#        <div class="col-6 col-lg-3 text-center margin-30px-bottom sm-margin-30px-top">
#         <a href="/inspirational-quotes/8441-everyone-has-a-right-to-peaceful-coexistence">
#          <img alt="Everyone has a right to peaceful coexistence, the basic personal freedoms, the alleviation of suffering, and the opportunity to lead a productive life. #&lt;Author:0x00007f6e50758210&gt;" class="margin-10px-bottom shadow" height="310" src="https://assets.passiton.com/quotes/quote_artwork/8441/medium/20250703_thursday_quote.jpg" width="310"/>
#         </a>
#         <h5 class="value_on_red">
#          <a href="/inspirational-quotes/8441-everyone-has-a-right-to-peaceful-coexistence">
#           FREEDOM
#          </a>
#         </h5>
#        </div>
#        <div class="col-6 col-lg-3 text-center margin-30px-bottom sm-margin-30px-top">
#         <a href="/inspirational-quotes/8385-true-patriotism-springs-from-a-belief-in-the">
#          <img alt="True patriotism springs from a belief in the dignity of the individual, freedom and equality not only for Americans but for all people on earth. #&lt;Author:0x00007f6e507547f0&gt;" class="margin-10px-bottom shadow" height="310" src="https://assets.passiton.com/quotes/quote_artwork/8385/medium/20250702_wednesday_quote.jpg" width="310"/>
#         </a>
#         <h5 class="value_on_red">
#          <a href="/inspirational-quotes/8385-true-patriotism-springs-from-a-belief-in-the">
#           FREEDOM
#          </a>
#         </h5>
#        </div>
#        <div class="col-6 col-lg-3 text-center margin-30px-bottom sm-margin-30px-top">
#         <a href="/inspirational-quotes/7776-may-we-think-of-freedom-not-as-the-right-to-do">
#          <img alt="May we think of freedom, not as the right to do as we please, but as the opportunity to do what is right. #&lt;Author:0x00007f6e50750970&gt;" class="margin-10px-bottom shadow" height="310" src="https://assets.passiton.com/quotes/quote_artwork/7776/medium/20250701_tuesday_quote.jpg" width="310"/>
#         </a>
#         <h5 class="value_on_red">
#          <a href="/inspirational-quotes/7776-may-we-think-of-freedom-not-as-the-right-to-do">
#           FREEDOM
#          </a>
#         </h5>
#        </div>
#        <div class="col-6 col-lg-3 text-center margin-30px-bottom sm-margin-30px-top">
#         <a href="/inspirational-quotes/7319-freedom-is-not-the-absence-of-commitments-but">
#          <img alt="Freedom is not the absence of commitments, but the ability to choose - and commit myself to - what is best for me. #&lt;Author:0x00007f6e5076ce40&gt;" class="margin-10px-bottom shadow" height="310" src="https://assets.passiton.com/quotes/quote_artwork/7319/medium/20250630_monday_quote.jpg" width="310"/>
#         </a>
#         <h5 class="value_on_red">
#          <a href="/inspirational-quotes/7319-freedom-is-not-the-absence-of-commitments-but">
#           FREEDOM
#          </a>
#         </h5>
#        </div>
#        <div class="col-6 col-lg-3 text-center margin-30px-bottom sm-margin-30px-top">
#         <a href="/inspirational-quotes/6862-education-is-the-most-powerful-weapon-which-you">
#          <img alt="Education is the most powerful weapon which you can use to change the world. #&lt;Author:0x00007f6e507696a0&gt;" class="margin-10px-bottom shadow" height="310" src="https://assets.passiton.com/quotes/quote_artwork/6862/medium/20250627_friday_quote.jpg" width="310"/>
#         </a>
#         <h5 class="value_on_red">
#          <a href="/inspirational-quotes/6862-education-is-the-most-powerful-weapon-which-you">
#           CHANGE
#          </a>
#         </h5>
#        </div>
#        <div class="col-6 col-lg-3 text-center margin-30px-bottom sm-margin-30px-top">
#         <a href="/inspirational-quotes/6427-when-we-are-no-longer-able-to-change-a">
#          <img alt="When we are no longer able to change a situation, we are challenged to change ourselves.  #&lt;Author:0x00007f6e507658c0&gt;" class="margin-10px-bottom shadow" height="310" src="https://assets.passiton.com/quotes/quote_artwork/6427/medium/20250626_thursday_quote.jpg" width="310"/>
#         </a>
#         <h5 class="value_on_red">
#          <a href="/inspirational-quotes/6427-when-we-are-no-longer-able-to-change-a">
#           CHANGE
#          </a>
#         </h5>
#        </div>
#        <div class="col-6 col-lg-3 text-center margin-30px-bottom sm-margin-30px-top">
#         <a href="/inspirational-quotes/8404-a-bend-in-the-road-is-not-the-end-of-the-road">
#          <img alt="A bend in the road is not the end of the road unless you fail to make the turn. #&lt;Author:0x00007f6e50761ae0&gt;" class="margin-10px-bottom shadow" height="310" src="https://assets.passiton.com/quotes/quote_artwork/8404/medium/20250625_wednesday_quote.jpg" width="310"/>
#         </a>
#         <h5 class="value_on_red">
#          <a href="/inspirational-quotes/8404-a-bend-in-the-road-is-not-the-end-of-the-road">
#           CHANGE
#          </a>
#         </h5>
#        </div>
#        <div class="col-6 col-lg-3 text-center margin-30px-bottom sm-margin-30px-top">
#         <a href="/inspirational-quotes/6506-yesterday-i-was-clever-so-i-wanted-to-change">
#          <img alt="Yesterday I was clever, so I wanted to change the world. Today I am wise, so I am changing myself. #&lt;Author:0x00007f6e5077cdb8&gt;" class="margin-10px-bottom shadow" height="310" src="https://assets.passiton.com/quotes/quote_artwork/6506/medium/20250624_tuesday_quote.jpg" width="310"/>
#         </a>
#         <h5 class="value_on_red">
#          <a href="/inspirational-quotes/6506-yesterday-i-was-clever-so-i-wanted-to-change">
#           CHANGE
#          </a>
#         </h5>
#        </div>
#        <div class="col-6 col-lg-3 text-center margin-30px-bottom sm-margin-30px-top">
#         <a href="/inspirational-quotes/8406-we-all-have-big-changes-in-our-lives-that-are">
#          <img alt="We all have big changes in our lives that are more or less a second chance. #&lt;Author:0x00007f6e50777c78&gt;" class="margin-10px-bottom shadow" height="310" src="https://assets.passiton.com/quotes/quote_artwork/8406/medium/20250623_monday_quote.jpg" width="310"/>
#         </a>
#         <h5 class="value_on_red">
#          <a href="/inspirational-quotes/8406-we-all-have-big-changes-in-our-lives-that-are">
#           CHANGE
#          </a>
#         </h5>
#        </div>
#        <div class="col-6 col-lg-3 text-center margin-30px-bottom sm-margin-30px-top">
#         <a href="/inspirational-quotes/8359-believe-in-yourself-and-go-for-it">
#          <img alt="Believe in yourself and go for it. #&lt;Author:0x00007f6e50771eb8&gt;" class="margin-10px-bottom shadow" height="310" src="https://assets.passiton.com/quotes/quote_artwork/8359/medium/20250620_friday_quote.jpg" width="310"/>
#         </a>
#         <h5 class="value_on_red">
#          <a href="/inspirational-quotes/8359-believe-in-yourself-and-go-for-it">
#           BELIEVE IN YOURSELF
#          </a>
#         </h5>
#        </div>
#        <div class="col-6 col-lg-3 text-center margin-30px-bottom sm-margin-30px-top">
#         <a href="/inspirational-quotes/7963-your-self-worth-is-determined-by-you-you-don-t">
#          <img alt="Your self-worth is determined by you. You don’t have to depend on someone telling you who you are. #&lt;Author:0x00007f6e5079c500&gt;" class="margin-10px-bottom shadow" height="310" src="https://assets.passiton.com/quotes/quote_artwork/7963/medium/20250619_thursday_quote.jpg" width="310"/>
#         </a>
#         <h5 class="value_on_red">
#          <a href="/inspirational-quotes/7963-your-self-worth-is-determined-by-you-you-don-t">
#           BELIEVE IN YOURSELF
#          </a>
#         </h5>
#        </div>
#        <div class="col-6 col-lg-3 text-center margin-30px-bottom sm-margin-30px-top">
#         <a href="/inspirational-quotes/8271-magic-is-believing-in-yourself-if-you-can-do">
#          <img alt="Magic is believing in yourself, if you can do that, you can make anything happen. #&lt;Author:0x00007f6e50796c40&gt;" class="margin-10px-bottom shadow" height="310" src="https://assets.passiton.com/quotes/quote_artwork/8271/medium/20250618_wednesday_quote.jpg" width="310"/>
#         </a>
#         <h5 class="value_on_red">
#          <a href="/inspirational-quotes/8271-magic-is-believing-in-yourself-if-you-can-do">
#           BELIEVE IN YOURSELF
#          </a>
#         </h5>
#        </div>
#        <div class="col-6 col-lg-3 text-center margin-30px-bottom sm-margin-30px-top">
#         <a href="/inspirational-quotes/6966-it-is-our-privilege-and-our-adventure-to">
#          <img alt="It is our privilege and our adventure to discover our own special light. #&lt;Author:0x00007f6e50792460&gt;" class="margin-10px-bottom shadow" height="310" src="https://assets.passiton.com/quotes/quote_artwork/6966/medium/20250617_tuesday_quote.jpg" width="310"/>
#         </a>
#         <h5 class="value_on_red">
#          <a href="/inspirational-quotes/6966-it-is-our-privilege-and-our-adventure-to">
#           BELIEVE IN YOURSELF
#          </a>
#         </h5>
#        </div>
#        <div class="col-6 col-lg-3 text-center margin-30px-bottom sm-margin-30px-top">
#         <a href="/inspirational-quotes/4915-you-are-braver-than-you-believe-smarter-than">
#          <img alt="You are braver than you believe, smarter than you seem, and stronger than you think. #&lt;Author:0x00007f6e507ae430&gt;" class="margin-10px-bottom shadow" height="310" src="https://assets.passiton.com/quotes/quote_artwork/4915/medium/20250616_monday_quote.jpg" width="310"/>
#         </a>
#         <h5 class="value_on_red">
#          <a href="/inspirational-quotes/4915-you-are-braver-than-you-believe-smarter-than">
#           BELIEVE IN YOURSELF
#          </a>
#         </h5>
#        </div>
#        <div class="col-6 col-lg-3 text-center margin-30px-bottom sm-margin-30px-top">
#         <a href="/inspirational-quotes/8446-my-father-gave-me-the-greatest-gift-anyone">
#          <img alt="My father gave me the greatest gift anyone could give another person: he believed in me. #&lt;Author:0x00007f6e507a97f0&gt;" class="margin-10px-bottom shadow" height="310" src="https://assets.passiton.com/quotes/quote_artwork/8446/medium/20250613_friday_quote_.jpg" width="310"/>
#         </a>
#         <h5 class="value_on_red">
#          <a href="/inspirational-quotes/8446-my-father-gave-me-the-greatest-gift-anyone">
#           JOY
#          </a>
#         </h5>
#        </div>
#        <div class="col-6 col-lg-3 text-center margin-30px-bottom sm-margin-30px-top">
#         <a href="/inspirational-quotes/8024-let-your-joy-be-in-your-journey-not-in-some">
#          <img alt="Let your joy be in your journey—not in some distant goal. #&lt;Author:0x00007f6e507a5010&gt;" class="margin-10px-bottom shadow" height="310" src="https://assets.passiton.com/quotes/quote_artwork/8024/medium/20250612_thursday_quote.jpg" width="310"/>
#         </a>
#         <h5 class="value_on_red">
#          <a href="/inspirational-quotes/8024-let-your-joy-be-in-your-journey-not-in-some">
#           JOY
#          </a>
#         </h5>
#        </div>
#        <div class="col-6 col-lg-3 text-center margin-30px-bottom sm-margin-30px-top">
#         <a href="/inspirational-quotes/7330-comparison-is-the-thief-of-joy">
#          <img alt="Comparison is the thief of joy. #&lt;Author:0x00007f6e507a0830&gt;" class="margin-10px-bottom shadow" height="310" src="https://assets.passiton.com/quotes/quote_artwork/7330/medium/20250611_wednesday_quote.jpg" width="310"/>
#         </a>
#         <h5 class="value_on_red">
#          <a href="/inspirational-quotes/7330-comparison-is-the-thief-of-joy">
#           JOY
#          </a>
#         </h5>
#        </div>
#        <div class="col-6 col-lg-3 text-center margin-30px-bottom sm-margin-30px-top">
#         <a href="/inspirational-quotes/7482-joy-is-a-decision-a-really-brave-one-about">
#          <img alt="Joy is a decision, a really brave one, about how you are going to respond to life. #&lt;Author:0x00007f6e5318b550&gt;" class="margin-10px-bottom shadow" height="310" src="https://assets.passiton.com/quotes/quote_artwork/7482/medium/20250610_tuesday_quote.jpg" width="310"/>
#         </a>
#         <h5 class="value_on_red">
#          <a href="/inspirational-quotes/7482-joy-is-a-decision-a-really-brave-one-about">
#           JOY
#          </a>
#         </h5>
#        </div>
#        <div class="col-6 col-lg-3 text-center margin-30px-bottom sm-margin-30px-top">
#         <a href="/inspirational-quotes/8321-joy-blooms-where-minds-and-hearts-are-open">
#          <img alt="Joy blooms where minds and hearts are open. #&lt;Author:0x00007f6e53187810&gt;" class="margin-10px-bottom shadow" height="310" src="https://assets.passiton.com/quotes/quote_artwork/8321/medium/20250609_monday_quote_.jpg" width="310"/>
#         </a>
#         <h5 class="value_on_red">
#          <a href="/inspirational-quotes/8321-joy-blooms-where-minds-and-hearts-are-open">
#           JOY
#          </a>
#         </h5>
#        </div>
#        <div class="col-6 col-lg-3 text-center margin-30px-bottom sm-margin-30px-top">
#         <a href="/inspirational-quotes/7352-the-real-voyage-of-discovery-consists-of-not-in">
#          <img alt="The real voyage of discovery consists of not in seeking new landscapes but in having new eyes. #&lt;Author:0x00007f6e53183990&gt;" class="margin-10px-bottom shadow" height="310" src="https://assets.passiton.com/quotes/quote_artwork/7352/medium/20250606_friday.jpg" width="310"/>
#         </a>
#         <h5 class="value_on_red">
#          <a href="/inspirational-quotes/7352-the-real-voyage-of-discovery-consists-of-not-in">
#           DISCOVERY
#          </a>
#         </h5>
#        </div>
#        <div class="col-6 col-lg-3 text-center margin-30px-bottom sm-margin-30px-top">
#         <a href="/inspirational-quotes/8340-there-are-always-new-things-to-find-out-if-you">
#          <img alt="There are always new things to find out if you go looking for them. #&lt;Author:0x00007f6e531be7e8&gt;" class="margin-10px-bottom shadow" height="310" src="https://assets.passiton.com/quotes/quote_artwork/8340/medium/20250605_thursday.jpg" width="310"/>
#         </a>
#         <h5 class="value_on_red">
#          <a href="/inspirational-quotes/8340-there-are-always-new-things-to-find-out-if-you">
#           DISCOVERY
#          </a>
#         </h5>
#        </div>
#        <div class="col-6 col-lg-3 text-center margin-30px-bottom sm-margin-30px-top">
#         <a href="/inspirational-quotes/8409-by-mutual-confidence-and-mutual-aid-great-deeds">
#          <img alt="By mutual confidence and mutual aid great deeds are done, and great discoveries made. #&lt;Author:0x00007f6e531b99c8&gt;" class="margin-10px-bottom shadow" height="310" src="https://assets.passiton.com/quotes/quote_artwork/8409/medium/20250604_wednesday.jpg" width="310"/>
#         </a>
#         <h5 class="value_on_red">
#          <a href="/inspirational-quotes/8409-by-mutual-confidence-and-mutual-aid-great-deeds">
#           DISCOVERY
#          </a>
#         </h5>
#        </div>
#        <div class="col-6 col-lg-3 text-center margin-30px-bottom sm-margin-30px-top">
#         <a href="/inspirational-quotes/7381-discovery-is-seeing-what-everybody-else-has">
#          <img alt="Discovery is seeing what everybody else has seen, and thinking what nobody else has thought. #&lt;Author:0x00007f6e531cff20&gt;" class="margin-10px-bottom shadow" height="310" src="https://assets.passiton.com/quotes/quote_artwork/7381/medium/20250603_tuesday.jpg" width="310"/>
#         </a>
#         <h5 class="value_on_red">
#          <a href="/inspirational-quotes/7381-discovery-is-seeing-what-everybody-else-has">
#           DISCOVERY
#          </a>
#         </h5>
#        </div>
#        <div class="col-6 col-lg-3 text-center margin-30px-bottom sm-margin-30px-top">
#         <a href="/inspirational-quotes/6823-you-have-to-leave-the-city-of-your-comfort-and">
#          <img alt="You have to leave the city of your comfort and go into the wilderness of your intuition. What you'll discover will be wonderful. What you'll discover is yourself. #&lt;Author:0x00007f6e531cae80&gt;" class="margin-10px-bottom shadow" height="310" src="https://assets.passiton.com/quotes/quote_artwork/6823/medium/20250602_monday.jpg" width="310"/>
#         </a>
#         <h5 class="value_on_red">
#          <a href="/inspirational-quotes/6823-you-have-to-leave-the-city-of-your-comfort-and">
#           DISCOVERY
#          </a>
#         </h5>
#        </div>
#        <div class="col-6 col-lg-3 text-center margin-30px-bottom sm-margin-30px-top">
#         <a href="/inspirational-quotes/7928-the-world-is-incomprehensibly-beautiful-an">
#          <img alt="The world is incomprehensibly beautiful—an endless prospect of magic and wonder. #&lt;Author:0x00007f6e531c5ca0&gt;" class="margin-10px-bottom shadow" height="310" src="https://assets.passiton.com/quotes/quote_artwork/7928/medium/20250530_friday_quote.jpg" width="310"/>
#         </a>
#         <h5 class="value_on_red">
#          <a href="/inspirational-quotes/7928-the-world-is-incomprehensibly-beautiful-an">
#           GET OUTSIDE
#          </a>
#         </h5>
#        </div>
#        <div class="col-6 col-lg-3 text-center margin-30px-bottom sm-margin-30px-top">
#         <a href="/inspirational-quotes/8131-nature-brings-solace-in-all-troubles">
#          <img alt="Nature brings solace in all troubles. #&lt;Author:0x00007f6e531c1240&gt;" class="margin-10px-bottom shadow" height="310" src="https://assets.passiton.com/quotes/quote_artwork/8131/medium/20250529_thursday_quote.jpg" width="310"/>
#         </a>
#         <h5 class="value_on_red">
#          <a href="/inspirational-quotes/8131-nature-brings-solace-in-all-troubles">
#           GET OUTSIDE
#          </a>
#         </h5>
#        </div>
#        <div class="col-6 col-lg-3 text-center margin-30px-bottom sm-margin-30px-top">
#         <a href="/inspirational-quotes/8380-the-wilderness-holds-answers-to-questions-we">
#          <img alt="The wilderness holds answers to questions we have not yet learned to ask. #&lt;Author:0x00007f6e531dd490&gt;" class="margin-10px-bottom shadow" height="310" src="https://assets.passiton.com/quotes/quote_artwork/8380/medium/20250528_wednesday_quote.jpg" width="310"/>
#         </a>
#         <h5 class="value_on_red">
#          <a href="/inspirational-quotes/8380-the-wilderness-holds-answers-to-questions-we">
#           GET OUTSIDE
#          </a>
#         </h5>
#        </div>
#        <div class="col-6 col-lg-3 text-center margin-30px-bottom sm-margin-30px-top">
#         <a href="/inspirational-quotes/8226-an-early-morning-walk-is-a-blessing-for-the">
#          <img alt="An early morning walk is a blessing for the whole day. #&lt;Author:0x00007f6e531d96b0&gt;" class="margin-10px-bottom shadow" height="310" src="https://assets.passiton.com/quotes/quote_artwork/8226/medium/20250527_tuesday_quote.jpg" width="310"/>
#         </a>
#         <h5 class="value_on_red">
#          <a href="/inspirational-quotes/8226-an-early-morning-walk-is-a-blessing-for-the">
#           GET OUTSIDE
#          </a>
#         </h5>
#        </div>
#        <div class="col-6 col-lg-3 text-center margin-30px-bottom sm-margin-30px-top">
#         <a href="/inspirational-quotes/8224-of-all-the-paths-you-take-in-life-make-sure-a">
#          <img alt="Of all the paths you take in life, make sure a few of them are dirt. #&lt;Author:0x00007f6e531d5bf0&gt;" class="margin-10px-bottom shadow" height="310" src="https://assets.passiton.com/quotes/quote_artwork/8224/medium/20250526_monday_quote.jpg" width="310"/>
#         </a>
#         <h5 class="value_on_red">
#          <a href="/inspirational-quotes/8224-of-all-the-paths-you-take-in-life-make-sure-a">
#           GET OUTSIDE
#          </a>
#         </h5>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div class="row">
#      <div class="col-12 text-center">
#       <div class="pagination-wrapper" id="pagination-container">
#        <nav aria-label="pager" class="pagination" role="navigation">
#         <span class="page current">
#          1
#         </span>
#         <span class="page">
#          <a href="/inspirational-quotes?page=2" rel="next">
#           2
#          </a>
#         </span>
#         <span class="page">
#          <a href="/inspirational-quotes?page=3">
#           3
#          </a>
#         </span>
#         <span class="page">
#          <a href="/inspirational-quotes?page=4">
#           4
#          </a>
#         </span>
#         <span class="page">
#          <a href="/inspirational-quotes?page=5">
#           5
#          </a>
#         </span>
#         <span class="page gap">
#          …
#         </span>
#         <span class="next">
#          <a href="/inspirational-quotes?page=2" rel="next">
#           Next ›
#          </a>
#         </span>
#         <span class="last">
#          <a href="/inspirational-quotes?page=79">
#           Last »
#          </a>
#         </span>
#        </nav>
#       </div>
#      </div>
#     </div>
#    </div>
#   </section>
#   <footer class="footer-classic-dark bg-extra-dark-gray padding-five-bottom sm-padding-30px-bottom">
#    <div class="bg-dark-footer padding-50px-tb sm-padding-30px-tb">
#     <div class="container">
#      <div class="row align-items-center">
#       <div class="col-lg-4 col-md-4 sm-text-center lg-text-left alt-font sm-margin-15px-bottom">
#        <a href="/">
#         <img alt="PassItOn.com The Foundation for a Better Life" class="footer_logo" data-rjs="/assets/site/passiton_fbl_logo-130047b5350655ed0505fbb6bf8d137784664a78481a2ed020a9b5b73c7ec3d9.png" src="/assets/site/passiton_fbl_logo-130047b5350655ed0505fbb6bf8d137784664a78481a2ed020a9b5b73c7ec3d9.png" style="max-width: 200px;"/>
#        </a>
#       </div>
#       <div class="col-lg-4 col-md-4 text-center sm-margin-10px-bottom">
#       </div>
#       <div class="col-lg-4 col-md-4 text-center">
#        <span class="alt-font margin-20px-right text-light-gray">
#         Follow us on social
#        </span>
#        <div class="social-icon-style-8 d-inline-block vertical-align-middle">
#         <ul class="small-icon mb-0">
#          <li>
#           <a aria-label="facebook" class="facebook text-white-2" href="https://www.facebook.com/valuescom" target="_blank">
#            <i aria-hidden="true" class="fab fa-facebook-f">
#            </i>
#           </a>
#          </li>
#          <li>
#           <a aria-label="twitter" class="twitter text-white-2" href="https://twitter.com/passiton_values" target="_blank">
#            <i class="fab fa-twitter">
#            </i>
#           </a>
#          </li>
#          <li>
#           <a aria-label="instagram" class="instagram text-white-2" href="https://www.instagram.com/passiton_values/" target="_blank">
#            <i aria-hidden="true" class="fab fa-instagram no-margin-right">
#            </i>
#           </a>
#          </li>
#          <li>
#           <a aria-label="pinterest" class="pinterest text-white-2" href="https://www.pinterest.com/passiton_values/" target="_blank">
#            <i aria-hidden="true" class="fab fa-pinterest no-margin-right">
#            </i>
#           </a>
#          </li>
#          <li>
#           <a aria-label="youtube" class="youtube text-white-2" href="https://www.youtube.com/c/passiton_values" target="_blank">
#            <i aria-hidden="true" class="fab fa-youtube no-margin-right">
#            </i>
#           </a>
#          </li>
#         </ul>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div class="footer-widget-area padding-five-top padding-30px-bottom sm-padding-30px-top">
#     <div class="container">
#      <div class="row">
#       <div class="col-lg-3 col-md-6 widget border-right border-color-medium-dark-gray padding-45px-left md-padding-15px-left md-no-border-right md-margin-30px-bottom text-center text-md-left">
#        <div class="widget-title alt-font text-small text-medium-gray text-uppercase margin-10px-bottom font-weight-600">
#         Pass It On
#        </div>
#        <ul class="list-unstyled">
#         <li>
#          <a class="text-small text-light-gray" href="/share-your-values">
#           Help Us Inspire Others
#          </a>
#         </li>
#        </ul>
#        <div class="widget-title alt-font text-small text-medium-gray text-uppercase margin-10px-bottom font-weight-600">
#         About Us
#        </div>
#        <ul class="list-unstyled">
#         <li>
#          <a class="text-small text-light-gray" href="/who-we-are">
#           About The Foundation for a Better Life
#          </a>
#         </li>
#         <li>
#          <a class="text-small text-light-gray" href="/faqs">
#           FAQs
#          </a>
#         </li>
#         <li>
#          <a class="text-small text-light-gray" href="/foundation-recognition">
#           Foundation Recognition
#          </a>
#         </li>
#         <li>
#          <a class="text-small text-light-gray" href="mailto:admin@passiton.com?subject=PassItOn.com%20Contact">
#           Contact Us
#          </a>
#         </li>
#        </ul>
#       </div>
#       <div class="col-lg-3 col-md-6 widget border-right border-color-medium-dark-gray padding-45px-left md-padding-15px-left md-no-border-right md-margin-30px-bottom text-center text-md-left">
#        <div class="widget-title alt-font text-small text-medium-gray text-uppercase margin-10px-bottom font-weight-600">
#         Be Inspired
#        </div>
#        <ul class="list-unstyled">
#         <li>
#          <a class="text-small text-light-gray" href="/teaching-values">
#           Teaching Values
#          </a>
#         </li>
#         <li>
#          <a class="text-small text-light-gray" href="/inspirational-quotes">
#           Inspirational Quotations
#          </a>
#         </li>
#         <li>
#          <a class="text-small text-light-gray" href="/inspirational-stories-tv-spots">
#           Pass It On® Videos
#          </a>
#         </li>
#         <li>
#          <a class="text-small text-light-gray" href="/artcenter-psas">
#           ArtCenter College of Design PSAs
#          </a>
#         </li>
#         <li>
#          <a class="text-small text-light-gray" href="/positive-good-news-stories">
#           Free Newspaper Stories
#          </a>
#         </li>
#         <li>
#          <a class="text-small text-light-gray" href="/inspirational-sayings-billboards">
#           Official Billboard Campaign
#          </a>
#         </li>
#         <li>
#          <a class="text-small text-light-gray" href="/inspirational-audio-stories">
#           Podcast
#          </a>
#         </li>
#         <li>
#          <a class="text-small text-light-gray" href="/radio">
#           Radio Ads
#          </a>
#         </li>
#         <li>
#          <a class="text-small text-light-gray" href="/passiton-blog">
#           Pass It On® Blog
#          </a>
#         </li>
#         <li>
#          <a class="text-small text-light-gray" href="/pass-it-on-ecards">
#           Send an Ecard
#          </a>
#         </li>
#        </ul>
#       </div>
#       <div class="col-lg-3 col-md-6 widget border-right border-color-medium-dark-gray padding-45px-left md-padding-15px-left md-no-border-right md-margin-30px-bottom text-center text-md-left">
#        <div class="widget-title alt-font text-small text-medium-gray text-uppercase margin-10px-bottom font-weight-600">
#         For Schools
#        </div>
#        <ul class="list-unstyled">
#         <li>
#          <a class="text-small text-light-gray" href="/poster-requests/new">
#           FREE Posters for Schools
#          </a>
#         </li>
#         <li>
#          <a class="text-small text-light-gray" href="/positive-good-news-stories">
#           <span class="new">
#            NEW
#           </span>
#           Inspirational Stories
#          </a>
#         </li>
#         <li>
#          <a class="text-small text-light-gray" href="/free-ebook/download">
#           <span class="new">
#            FREE
#           </span>
#           PassItOn® Stories eBook
#          </a>
#         </li>
#         <li>
#          <a class="text-small text-light-gray" href="/pass-it-on-downloads">
#           PDF Poster Downloads
#          </a>
#         </li>
#         <li>
#          <a class="text-small text-light-gray" href="/pass-it-on-downloads#passiton_bookmarks">
#           Bookmark Downloads
#          </a>
#         </li>
#        </ul>
#        <div class="widget-title alt-font text-small text-medium-gray text-uppercase margin-10px-bottom font-weight-600">
#         <i aria-hidden="true" class="fas fa-globe d-none d-lg-inline text-normal">
#         </i>
#        </div>
#        <ul class="list-unstyled">
#         <li>
#          <a class="text-small text-light-gray" href="https://www.pasala.org/" target="_blank">
#           Español | Spanish
#          </a>
#         </li>
#         <li>
#          <a class="text-small text-light-gray" href="https://www.umavidamelhor.org/" target="_blank">
#           Português | Portuguese
#          </a>
#         </li>
#         <li>
#          <a class="text-small text-light-gray" href="https://www.values.cn.com/" target="_blank">
#           中文 | Chinese
#          </a>
#         </li>
#        </ul>
#       </div>
#       <div class="col-lg-3 col-md-6 widget padding-45px-left md-padding-15px-left md-no-border-right md-margin-30px-bottom text-center text-md-left">
#        <div class="widget-title alt-font text-small text-medium-gray text-uppercase margin-10px-bottom font-weight-600">
#         For Media Companies
#        </div>
#        <ul class="list-unstyled">
#         <li>
#          <a class="text-small text-light-gray" href="/for-media-companies">
#           For Media Companies
#          </a>
#         </li>
#         <li>
#          <a class="text-small text-light-gray" href="https://www.passiton-media.com">
#           Broadcast Quality PSA Downloads
#          </a>
#         </li>
#         <li>
#          <a class="text-small text-light-gray" href="https://www.passiton-media.com">
#           Pass It On Radio Ads
#          </a>
#         </li>
#         <li>
#          <a class="text-small text-light-gray" href="https://www.passiton-media.com">
#           Live Reads
#          </a>
#         </li>
#         <li>
#          <a class="text-small text-light-gray" href="https://www.passiton-media.com">
#           Out of Home Materials
#          </a>
#         </li>
#        </ul>
#        <div class="row sm-margin-30px-top">
#         <div class="col-lg-4">
#          <a href="/">
#           <img alt="values.com logo" src="/assets/site/values_logo-d2f298a8d307ac7a45b2651f13796052ecfd37d37d73b102f7c910ee6e2eabc2.png" style="max-width: 70px;"/>
#          </a>
#         </div>
#         <div class="col-lg-7">
#          <p class="text-light-gray text-small padding-10px-top">
#           VALUES.COM
#           <small>
#            ®
#           </small>
#           is now PassItOn.com
#           <small>
#            ®
#           </small>
#          </p>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div class="container">
#     <div class="footer-bottom border-top border-color-medium-dark-gray padding-30px-top">
#      <div class="row">
#       <div class="col-lg-6 col-md-6 text-small text-light-gray text-md-left text-center">
#        ©2000-2025 The Foundation for a Better Life.
#        <span class="cookies_preference">
#        </span>
#       </div>
#       <div class="col-lg-6 col-md-6 text-small text-light-gray text-md-right text-center">
#        <a class="text-light-gray" href="/privacy-policy">
#         Privacy Policy
#        </a>
#        |
#        <a class="text-light-gray" href="/terms-of-use">
#         Terms of Use
#        </a>
#       </div>
#      </div>
#     </div>
#    </div>
#   </footer>
#   <a class="scroll-top-arrow" href="javascript:void(0);">
#    <i class="ti-arrow-up">
#    </i>
#   </a>
#   <script data-turbo-track="reload" src="/assets/application-f82533d83ecf747ec28f830cabfa0c02bf7f274da6760f54f791616da12991f9.js">
#   </script>
#   <script crossorigin="anonymous" integrity="sha384-UO2eT0CpHqdSJQ6hJty5KVphtPhzWj9WO1clHTMGa3JDZwrnQq4sF86dIHNDz0W1" src="https://cdnjs.cloudflare.com/ajax/libs/popper.js/1.14.7/umd/popper.min.js">
#   </script>
#   <script crossorigin="anonymous" integrity="sha384-JjSmVgyd0p3pXB1rRibZUAYoIIy6OrQ6VrjIEaFf/nJGzIxFDsf4x0xIM+B07jRM" src="https://stackpath.bootstrapcdn.com/bootstrap/4.3.1/js/bootstrap.min.js">
#   </script>
#   <script src="https://cdnjs.cloudflare.com/ajax/libs/jquery-jcrop/0.9.15/js/jquery.Jcrop.min.js">
#   </script>
#   <div class="zoom-anim-dialog mfp-hide col-xl-6 col-lg-6 col-md-7 col-11 mx-auto bg-white text-center modal-popup-main padding-50px-all" id="download_ebook">
#    <a href="/inspirational-quotes/4468-careers-like-rockets-dont-always-take-off-on">
#     <img alt="Careers, like rockets, don't always take off on schedule. The key is to keep working the engines. #&lt;Author:0x00007f6e531f7598&gt;" class="margin-10px-bottom shadow" height="310" src="https://assets.passiton.com/quotes/quote_artwork/4468/medium/20250709_wednesday_quote.jpg" width="310"/>
#    </a>
#    <h6 class="font-weight-300 text-black margin-20px-bottom sm-margin-15px-bottom">
#     Get our FREE daily quote emails!
#    </h6>
#    <p class="text-medium text-black width-70 mx-auto margin-40px-bottom sm-width-100 sm-margin-15px-bottom">
#     Get a daily inspirational quote in your inbox each weekday! Enter your email below to subscribe.
#    </p>
#    <form accept-charset="UTF-8" action="/users" class="simple_form search-box3 margin-10px-bottom" id="new_user" method="post" novalidate="novalidate">
#     <input autocomplete="off" name="authenticity_token" type="hidden" value="NcU53H4b5wpel9hRxrlJSrBt-OtOwzMEaEi8jOUDvEt717HIoIRURxtREJ44v-M1mCy7teQpnDgXDEU5gBsShQ"/>
#     <div class="input-group add-on width-75 mx-auto sm-width-100">
#      <input class="string email optional form-control text-black" id="user_email" label="false" name="user[email]" placeholder="you@youremail.com" type="text" value=""/>
#      <div class="input-group-append">
#       <button aria-label="Submit" class="btn btn-default" type="submit">
#        <i class="ti-arrow-right text-small m-0">
#        </i>
#       </button>
#      </div>
#     </div>
#     <div class="cf-turnstile margin-10px-top" data-callback="javascriptCallback" data-sitekey="0x4AAAAAAASgRtNBQYE3dg9n">
#     </div>
#    </form>
#   </div>
#   <script data-turbo-track="reload" src="/assets/popups-5be7eec5eadc229f31cf65159c7edf53c088e3bdaa688699c6115e11b3ce5e31.js">
#   </script>
#   <div class="cookies_consent w-100 wow fadeIn">
#    <span class="text-white alt-font mb-0 padding-20px-bottom">
#     We use cookies or similar technologies to process data when you visit our site. This data may relate to your use of our site, your preferences, your device, or other information about you. We and third parties may use this information for a variety of purposes, such as enabling the sites to function, to personalize your experience when using our sites, and for analytical purposes. Read our
#     <a class="text-white text-decoration-underline" href="/privacy-policy">
#      privacy policy
#     </a>
#     and
#     <a class="text-white text-decoration-underline" href="/terms-of-use">
#      terms of use
#     </a>
#     for details.
#    </span>
#    <a class="text-white close_cookies_consent" data-remote="true" href="/cookies?cookies_accepted=rejected">
#     <i aria-hidden="true" class="fas fa-window-close d-lg-inline text-normal">
#     </i>
#     close
#    </a>
#    <br/>
#    <br/>
#    <a class="btn btn-small btn-white btn-rounded" data-remote="true" href="/cookies?cookies_accepted=rejected">
#     Reject All
#    </a>
#    <a class="btn btn-small btn-white btn-rounded" data-remote="true" href="/cookies?cookies_accepted=accepted">
#     Accept All
#    </a>
#   </div>
#  </body>
# </html>

# %%
import csv

quotes=[]  # a list to store quotes
   
table = soup.find('div', attrs = {'id':'all_quotes'})

# %%
for row in table.findAll('div',
                         attrs = {'class':'col-6 col-lg-3 text-center margin-30px-bottom sm-margin-30px-top'}):
    quote = {}
    quote['theme'] = row.h5.text
    quote['url'] = row.a['href']
    quote['img'] = row.img['src']
    quote['lines'] = row.img['alt'].split(" #")[0]
    quote['author'] = row.img['alt'].split(" #")[1]
    quotes.append(quote)

# %%
filename = 'inspirational_quotes.csv'
with open(filename, 'w', newline='', encoding='utf-8') as f:
    w = csv.DictWriter(f,['theme','url','img','lines','author'])
    w.writeheader()
    for quote in quotes:
        w.writerow(quote)

# %%
import pandas as pd 

df = pd.read_csv(filename, encoding='utf-8')
df
# Out:
#                   theme                                                url  \
# 0             HARD WORK  /inspirational-quotes/4468-careers-like-rocket...
# 1             HARD WORK  /inspirational-quotes/8378-doing-the-best-at-t...
# 2             HARD WORK  /inspirational-quotes/6188-far-and-away-the-be...
# 3               FREEDOM  /inspirational-quotes/8447-from-every-mountain...
# 4               FREEDOM  /inspirational-quotes/8441-everyone-has-a-righ...
# 5               FREEDOM  /inspirational-quotes/8385-true-patriotism-spr...
# 6               FREEDOM  /inspirational-quotes/7776-may-we-think-of-fre...
# 7               FREEDOM  /inspirational-quotes/7319-freedom-is-not-the-...
# 8                CHANGE  /inspirational-quotes/6862-education-is-the-mo...
# 9                CHANGE  /inspirational-quotes/6427-when-we-are-no-long...
# 10               CHANGE  /inspirational-quotes/8404-a-bend-in-the-road-...
# 11               CHANGE  /inspirational-quotes/6506-yesterday-i-was-cle...
# 12               CHANGE  /inspirational-quotes/8406-we-all-have-big-cha...
# 13  BELIEVE IN YOURSELF  /inspirational-quotes/8359-believe-in-yourself...
# 14  BELIEVE IN YOURSELF  /inspirational-quotes/7963-your-self-worth-is-...
# 15  BELIEVE IN YOURSELF  /inspirational-quotes/8271-magic-is-believing-...
# 16  BELIEVE IN YOURSELF  /inspirational-quotes/6966-it-is-our-privilege...
# 17  BELIEVE IN YOURSELF  /inspirational-quotes/4915-you-are-braver-than...
# 18                  JOY  /inspirational-quotes/8446-my-father-gave-me-t...
# 19                  JOY  /inspirational-quotes/8024-let-your-joy-be-in-...
# 20                  JOY  /inspirational-quotes/7330-comparison-is-the-t...
# 21                  JOY  /inspirational-quotes/7482-joy-is-a-decision-a...
# 22                  JOY  /inspirational-quotes/8321-joy-blooms-where-mi...
# 23            DISCOVERY  /inspirational-quotes/7352-the-real-voyage-of-...
# 24            DISCOVERY  /inspirational-quotes/8340-there-are-always-ne...
# 25            DISCOVERY  /inspirational-quotes/8409-by-mutual-confidenc...
# 26            DISCOVERY  /inspirational-quotes/7381-discovery-is-seeing...
# 27            DISCOVERY  /inspirational-quotes/6823-you-have-to-leave-t...
# 28          GET OUTSIDE  /inspirational-quotes/7928-the-world-is-incomp...
# 29          GET OUTSIDE  /inspirational-quotes/8131-nature-brings-solac...
# 30          GET OUTSIDE  /inspirational-quotes/8380-the-wilderness-hold...
# 31          GET OUTSIDE  /inspirational-quotes/8226-an-early-morning-wa...
# 32          GET OUTSIDE  /inspirational-quotes/8224-of-all-the-paths-yo...
#
#                                                   img  \
# 0   https://assets.passiton.com/quotes/quote_artwo...
# 1   https://assets.passiton.com/quotes/quote_artwo...
# 2   https://assets.passiton.com/quotes/quote_artwo...
# 3   https://assets.passiton.com/quotes/quote_artwo...
# 4   https://assets.passiton.com/quotes/quote_artwo...
# 5   https://assets.passiton.com/quotes/quote_artwo...
# 6   https://assets.passiton.com/quotes/quote_artwo...
# 7   https://assets.passiton.com/quotes/quote_artwo...
# 8   https://assets.passiton.com/quotes/quote_artwo...
# 9   https://assets.passiton.com/quotes/quote_artwo...
# 10  https://assets.passiton.com/quotes/quote_artwo...
# 11  https://assets.passiton.com/quotes/quote_artwo...
# 12  https://assets.passiton.com/quotes/quote_artwo...
# 13  https://assets.passiton.com/quotes/quote_artwo...
# 14  https://assets.passiton.com/quotes/quote_artwo...
# 15  https://assets.passiton.com/quotes/quote_artwo...
# 16  https://assets.passiton.com/quotes/quote_artwo...
# 17  https://assets.passiton.com/quotes/quote_artwo...
# 18  https://assets.passiton.com/quotes/quote_artwo...
# 19  https://assets.passiton.com/quotes/quote_artwo...
# 20  https://assets.passiton.com/quotes/quote_artwo...
# 21  https://assets.passiton.com/quotes/quote_artwo...
# 22  https://assets.passiton.com/quotes/quote_artwo...
# 23  https://assets.passiton.com/quotes/quote_artwo...
# 24  https://assets.passiton.com/quotes/quote_artwo...
# 25  https://assets.passiton.com/quotes/quote_artwo...
# 26  https://assets.passiton.com/quotes/quote_artwo...
# 27  https://assets.passiton.com/quotes/quote_artwo...
# 28  https://assets.passiton.com/quotes/quote_artwo...
# 29  https://assets.passiton.com/quotes/quote_artwo...
# 30  https://assets.passiton.com/quotes/quote_artwo...
# 31  https://assets.passiton.com/quotes/quote_artwo...
# 32  https://assets.passiton.com/quotes/quote_artwo...
#
#                                                 lines  \
# 0   Careers, like rockets, don't always take off o...
# 1   Doing the best at this moment puts you in the ...
# 2   Far and away the best prize that life offers i...
# 3          From every mountainside, let freedom ring.
# 4   Everyone has a right to peaceful coexistence, ...
# 5   True patriotism springs from a belief in the d...
# 6   May we think of freedom, not as the right to d...
# 7   Freedom is not the absence of commitments, but...
# 8   Education is the most powerful weapon which yo...
# 9   When we are no longer able to change a situati...
# 10  A bend in the road is not the end of the road ...
# 11  Yesterday I was clever, so I wanted to change ...
# 12  We all have big changes in our lives that are ...
# 13                 Believe in yourself and go for it.
# 14  Your self-worth is determined by you. You don’...
# 15  Magic is believing in yourself, if you can do ...
# 16  It is our privilege and our adventure to disco...
# 17  You are braver than you believe, smarter than ...
# 18  My father gave me the greatest gift anyone cou...
# 19  Let your joy be in your journey—not in some di...
# 20                    Comparison is the thief of joy.
# 21  Joy is a decision, a really brave one, about h...
# 22        Joy blooms where minds and hearts are open.
# 23  The real voyage of discovery consists of not i...
# 24  There are always new things to find out if you...
# 25  By mutual confidence and mutual aid great deed...
# 26  Discovery is seeing what everybody else has se...
# 27  You have to leave the city of your comfort and...
# 28  The world is incomprehensibly beautiful—an end...
# 29              Nature brings solace in all troubles.
# 30  The wilderness holds answers to questions we h...
# 31  An early morning walk is a blessing for the wh...
# 32  Of all the paths you take in life, make sure a...
#
#                          author
# 0   <Author:0x00007f6e506f7320>
# 1   <Author:0x00007f6e506f3680>
# 2   <Author:0x00007f6e506f0340>
# 3   <Author:0x00007f6e5075bff0>
# 4   <Author:0x00007f6e50758210>
# 5   <Author:0x00007f6e507547f0>
# 6   <Author:0x00007f6e50750970>
# 7   <Author:0x00007f6e5076ce40>
# 8   <Author:0x00007f6e507696a0>
# 9   <Author:0x00007f6e507658c0>
# 10  <Author:0x00007f6e50761ae0>
# 11  <Author:0x00007f6e5077cdb8>
# 12  <Author:0x00007f6e50777c78>
# 13  <Author:0x00007f6e50771eb8>
# 14  <Author:0x00007f6e5079c500>
# 15  <Author:0x00007f6e50796c40>
# 16  <Author:0x00007f6e50792460>
# 17  <Author:0x00007f6e507ae430>
# 18  <Author:0x00007f6e507a97f0>
# 19  <Author:0x00007f6e507a5010>
# 20  <Author:0x00007f6e507a0830>
# 21  <Author:0x00007f6e5318b550>
# 22  <Author:0x00007f6e53187810>
# 23  <Author:0x00007f6e53183990>
# 24  <Author:0x00007f6e531be7e8>
# 25  <Author:0x00007f6e531b99c8>
# 26  <Author:0x00007f6e531cff20>
# 27  <Author:0x00007f6e531cae80>
# 28  <Author:0x00007f6e531c5ca0>
# 29  <Author:0x00007f6e531c1240>
# 30  <Author:0x00007f6e531dd490>
# 31  <Author:0x00007f6e531d96b0>
# 32  <Author:0x00007f6e531d5bf0>
